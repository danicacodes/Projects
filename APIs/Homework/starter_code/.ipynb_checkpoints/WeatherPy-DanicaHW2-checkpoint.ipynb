# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import matplotlib as mpl

# set the style as 'bmh'
mpl.style.use('bmh')


# Import API key
from api_keys import api_key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Weather API Key
api_key = api_keys.api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create empty list
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start counter
record = 1

# Log file 
print("Beginning Data Retrieval")
print("-----------------------------")

# Loop through cities
for city in cities:
    
    try:
        response = requests.get(f"{url}&q={city}").json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
              
        # Increases counter by one
        record = record + 1
        
        # timer to not exceed limit of API
        time.sleep(1.01)
     
    # Skip if city not found           
    except: 
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=beloha
# Processing Record 2 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cape town
# City not found. Skipping...
# Processing Record 3 | Moratuwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=moratuwa
# Processing Record 4 | San Miguel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=san miguel
# Processing Record 5 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bluff
# Processing Record 6 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nikolskoye
# City not found. Skipping...
# Processing Record 7 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=new norfolk
# City not found. Skipping...
# Processing Record 8 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hermanus
# Processing Record 9 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ushuaia
# Processing Record 10 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tuatapere
# Processing Record 11 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bathsheba
# Processing Record 12 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=rikitea
# Processing Record 13 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=jamestown
# Processing Record 14 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hithadhoo
# Processing Record 15 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=poum
# Processing Record 16 | Stavnsholt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=stavnsholt
# Processing Record 17 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=longyearbyen
# Processing Record 18 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ponta do sol
# Processing Record 19 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mataura
# Processing Record 20 | Genc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=genc
# Processing Record 21 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tasiilaq
# Processing Record 22 | Terney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=terney
# Processing Record 23 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=carnarvon
# Processing Record 24 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=los llanos de aridane
# Processing Record 25 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=butaritari
# Processing Record 26 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=upernavik
# Processing Record 27 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bredasdorp
# Processing Record 28 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=iqaluit
# Processing Record 29 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=khatanga
# City not found. Skipping...
# Processing Record 30 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=arraial do cabo
# Processing Record 31 | Yaransk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=yaransk
# Processing Record 32 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=grindavik
# Processing Record 33 | Quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=quelimane
# Processing Record 34 | Bira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bira
# Processing Record 35 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=faanui
# Processing Record 36 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=havre-saint-pierre
# Processing Record 37 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=puerto ayora
# Processing Record 38 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=atuona
# Processing Record 39 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=saldanha
# Processing Record 40 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bandarbeyla
# City not found. Skipping...
# Processing Record 41 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=airai
# Processing Record 42 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sao filipe
# Processing Record 43 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=port alfred
# Processing Record 44 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=chokurdakh
# Processing Record 45 | Fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=fukue
# Processing Record 46 | Leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=leh
# Processing Record 47 | Makungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=makungu
# Processing Record 48 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kapaa
# City not found. Skipping...
# Processing Record 49 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=taoudenni
# Processing Record 50 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=te anau
# Processing Record 51 | Chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=chicama
# Processing Record 52 | Wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=wanning
# Processing Record 53 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ribeira grande
# Processing Record 54 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hilo
# Processing Record 55 | Atocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=atocha
# Processing Record 56 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=belmonte
# Processing Record 57 | Muli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=muli
# Processing Record 58 | Timmins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=timmins
# Processing Record 59 | Syracuse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=syracuse
# Processing Record 60 | Mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mitu
# Processing Record 61 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=barrow
# Processing Record 62 | Siwana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=siwana
# Processing Record 63 | Orda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=orda
# Processing Record 64 | Slavutych
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=slavutych
# Processing Record 65 | Bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bowen
# Processing Record 66 | Dehloran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=dehloran
# Processing Record 67 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=albany
# City not found. Skipping...
# Processing Record 68 | Ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ulladulla
# Processing Record 69 | Hokitika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hokitika
# Processing Record 70 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=saskylakh
# Processing Record 71 | Ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ayan
# Processing Record 72 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=busselton
# Processing Record 73 | Cajati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cajati
# Processing Record 74 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=saint george
# City not found. Skipping...
# Processing Record 75 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=qaanaaq
# Processing Record 76 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sioux lookout
# Processing Record 77 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=port elizabeth
# Processing Record 78 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kodiak
# Processing Record 79 | Liverpool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=liverpool
# Processing Record 80 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mar del plata
# Processing Record 81 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=yellowknife
# City not found. Skipping...
# Processing Record 82 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cidreira
# Processing Record 83 | Male
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=male
# Processing Record 84 | La Rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=la rioja
# Processing Record 85 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tiksi
# Processing Record 86 | Rosarito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=rosarito
# Processing Record 87 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=aklavik
# Processing Record 88 | Valle Hermoso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=valle hermoso
# Processing Record 89 | Mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mahajanga
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 90 | Launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=launceston
# Processing Record 91 | Tianpeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tianpeng
# Processing Record 92 | Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=matara
# City not found. Skipping...
# Processing Record 93 | Tanout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tanout
# Processing Record 94 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hamilton
# Processing Record 95 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=avarua
# Processing Record 96 | Tete
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tete
# Processing Record 97 | Isla Mujeres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=isla mujeres
# Processing Record 98 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mehamn
# Processing Record 99 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vaini
# City not found. Skipping...
# Processing Record 100 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mount isa
# Processing Record 101 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=san patricio
# Processing Record 102 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cayenne
# Processing Record 103 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=namibe
# Processing Record 104 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=east london
# Processing Record 105 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vestmannaeyjar
# Processing Record 106 | Xichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=xichang
# Processing Record 107 | Siguiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=siguiri
# Processing Record 108 | Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kenai
# City not found. Skipping...
# Processing Record 109 | Filadelfia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=filadelfia
# Processing Record 110 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kaeo
# Processing Record 111 | Yakeshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=yakeshi
# Processing Record 112 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=portland
# Processing Record 113 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=port lincoln
# Processing Record 114 | Pedernales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pedernales
# Processing Record 115 | Sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sorong
# Processing Record 116 | Rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=rundu
# Processing Record 117 | Toora-Khem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=toora-khem
# Processing Record 118 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sao joao da barra
# Processing Record 119 | Kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kloulklubed
# City not found. Skipping...
# Processing Record 120 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=thinadhoo
# Processing Record 121 | Gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=gornopravdinsk
# Processing Record 122 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lebu
# Processing Record 123 | Redwater
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=redwater
# Processing Record 124 | Sidi Ali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sidi ali
# Processing Record 125 | Tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tiarei
# Processing Record 126 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=yar-sale
# Processing Record 127 | Krasnogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=krasnogorsk
# Processing Record 128 | Palimbang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=palimbang
# Processing Record 129 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=katsuura
# Processing Record 130 | Bratsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bratsk
# Processing Record 131 | Vigrestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vigrestad
# Processing Record 132 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=saint-philippe
# Processing Record 133 | Jutai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=jutai
# Processing Record 134 | Itacarambi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=itacarambi
# Processing Record 135 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kaitangata
# Processing Record 136 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sola
# Processing Record 137 | Karatuzskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=karatuzskoye
# Processing Record 138 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=karratha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 139 | Aguilas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=aguilas
# Processing Record 140 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=georgetown
# City not found. Skipping...
# Processing Record 141 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hobart
# Processing Record 142 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=souillac
# Processing Record 143 | Itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=itoman
# Processing Record 144 | Hay River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hay river
# Processing Record 145 | Saint-Leu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=saint-leu
# Processing Record 146 | Palestine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=palestine
# City not found. Skipping...
# Processing Record 147 | Rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=rosario
# Processing Record 148 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=komsomolskiy
# Processing Record 149 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=san quintin
# Processing Record 150 | Chipinge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=chipinge
# Processing Record 151 | Kamen-Rybolov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kamen-rybolov
# Processing Record 152 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pacific grove
# Processing Record 153 | Werda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=werda
# Processing Record 154 | Novoasbest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=novoasbest
# Processing Record 155 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=itarema
# Processing Record 156 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tuktoyaktuk
# Processing Record 157 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=torbay
# Processing Record 158 | Huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=huarmey
# Processing Record 159 | Hastings
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hastings
# Processing Record 160 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=port blair
# Processing Record 161 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=camacha
# Processing Record 162 | Volchikha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=volchikha
# Processing Record 163 | Diyarb Najm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=diyarb najm
# Processing Record 164 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=dikson
# Processing Record 165 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=shingu
# Processing Record 166 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cherskiy
# Processing Record 167 | Kyaukse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kyaukse
# Processing Record 168 | Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nelson bay
# Processing Record 169 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=labuhan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 170 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=narsaq
# City not found. Skipping...
# Processing Record 171 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ancud
# Processing Record 172 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=punta arenas
# Processing Record 173 | Santa Isabel do Rio Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=santa isabel do rio negro
# City not found. Skipping...
# Processing Record 174 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mahebourg
# Processing Record 175 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=caravelas
# Processing Record 176 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kruisfontein
# Processing Record 177 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lompoc
# Processing Record 178 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=fort nelson
# Processing Record 179 | Flin Flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=flin flon
# Processing Record 180 | Nago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nago
# City not found. Skipping...
# Processing Record 181 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=rio gallegos
# Processing Record 182 | Golyshmanovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=golyshmanovo
# Processing Record 183 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=norman wells
# City not found. Skipping...
# Processing Record 184 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=provideniya
# Processing Record 185 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nome
# City not found. Skipping...
# Processing Record 186 | Nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nhulunbuy
# Processing Record 187 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=salalah
# Processing Record 188 | Salekhard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=salekhard
# Processing Record 189 | Peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=peniche
# Processing Record 190 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kahului
# Processing Record 191 | Asosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=asosa
# Processing Record 192 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=rawson
# Processing Record 193 | Ordu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ordu
# City not found. Skipping...
# Processing Record 194 | Kibondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kibondo
# City not found. Skipping...
# Processing Record 195 | Karasjok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=karasjok
# Processing Record 196 | Bezenchuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bezenchuk
# Processing Record 197 | Basoko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=basoko
# Processing Record 198 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=avera
# Processing Record 199 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bilibino
# Processing Record 200 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=victoria
# Processing Record 201 | Nouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nouakchott
# Processing Record 202 | Xinmin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=xinmin
# Processing Record 203 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vao
# Processing Record 204 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=luderitz
# Processing Record 205 | Noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=noumea
# Processing Record 206 | Papayal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=papayal
# Processing Record 207 | Turayf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=turayf
# Processing Record 208 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=zhigansk
# Processing Record 209 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=henties bay
# Processing Record 210 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=broome
# Processing Record 211 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mount gambier
# Processing Record 212 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hasaki
# Processing Record 213 | Kutoarjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kutoarjo
# Processing Record 214 | Teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=teya
# Processing Record 215 | Warri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=warri
# Processing Record 216 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=chuy
# Processing Record 217 | Macas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=macas
# City not found. Skipping...
# Processing Record 218 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=carutapera
# Processing Record 219 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hofn
# Processing Record 220 | Ust-Kan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ust-kan
# Processing Record 221 | Darasun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=darasun
# Processing Record 222 | Sampit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sampit
# Processing Record 223 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nuuk
# Processing Record 224 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=constitucion
# Processing Record 225 | Bondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bondo
# Processing Record 226 | Gashua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=gashua
# Processing Record 227 | Boca do Acre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=boca do acre
# Processing Record 228 | Poltava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=poltava
# Processing Record 229 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=port macquarie
# Processing Record 230 | Marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=marystown
# Processing Record 231 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lavrentiya
# Processing Record 232 | Ilhabela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ilhabela
# Processing Record 233 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=castro
# City not found. Skipping...
# Processing Record 234 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vardo
# Processing Record 235 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=geraldton
# Processing Record 236 | Kota Kinabalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kota kinabalu
# Processing Record 237 | Udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=udachnyy
# Processing Record 238 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bambous virieux
# Processing Record 239 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=egvekinot
# City not found. Skipping...
# Processing Record 240 | Puri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=puri
# Processing Record 241 | Gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=gizo
# Processing Record 242 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=acapulco
# Processing Record 243 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=severo-kurilsk
# Processing Record 244 | Tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tiznit
# Processing Record 245 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pangnirtung
# Processing Record 246 | Itapirapua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=itapirapua
# Processing Record 247 | Vaitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vaitape
# City not found. Skipping...
# Processing Record 248 | Millbrook
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=millbrook
# Processing Record 249 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=san cristobal
# Processing Record 250 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=anadyr
# Processing Record 251 | Tuy Hoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tuy hoa
# Processing Record 252 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pevek
# Processing Record 253 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=margate
# Processing Record 254 | Ferrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ferrol
# Processing Record 255 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pisco
# Processing Record 256 | Angostura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=angostura
# Processing Record 257 | Juventino Rosas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=juventino rosas
# Processing Record 258 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=touros
# City not found. Skipping...
# Processing Record 259 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=maniitsoq
# Processing Record 260 | La Baule-Escoublac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=la baule-escoublac
# Processing Record 261 | Stovring
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=stovring
# Processing Record 262 | Pavlodar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pavlodar
# Processing Record 263 | Ilebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ilebo
# Processing Record 264 | Baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=baykit
# Processing Record 265 | Salinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=salinas
# Processing Record 266 | Aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=aksu
# Processing Record 267 | Madang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=madang
# Processing Record 268 | Minab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=minab
# City not found. Skipping...
# Processing Record 269 | Singarayakonda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=singarayakonda
# Processing Record 270 | Naliya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=naliya
# Processing Record 271 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=thompson
# Processing Record 272 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ponta delgada
# City not found. Skipping...
# Processing Record 273 | Saravan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=saravan
# City not found. Skipping...
# Processing Record 274 | Makokou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=makokou
# Processing Record 275 | Matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=matagami
# Processing Record 276 | Haukipudas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=haukipudas
# Processing Record 277 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=husavik
# Processing Record 278 | Ibra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ibra
# City not found. Skipping...
# Processing Record 279 | Sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sangar
# Processing Record 280 | Pemba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pemba
# Processing Record 281 | Missoula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=missoula
# City not found. Skipping...
# Processing Record 282 | Sungairaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sungairaya
# Processing Record 283 | Fortuna Foothills
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=fortuna foothills
# Processing Record 284 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=westport
# Processing Record 285 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bethel
# Processing Record 286 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cabo san lucas
# Processing Record 287 | Rauma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=rauma
# City not found. Skipping...
# Processing Record 288 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=berlevag
# Processing Record 289 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sur
# Processing Record 290 | Tabas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tabas
# Processing Record 291 | Inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=inirida
# Processing Record 292 | The Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=the valley
# Processing Record 293 | Balabac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=balabac
# Processing Record 294 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kieta
# Processing Record 295 | Mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mackay
# Processing Record 296 | Baturaja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=baturaja
# Processing Record 297 | Jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=jacareacanga
# Processing Record 298 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=laguna
# Processing Record 299 | Harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=harper
# Processing Record 300 | Gillette
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=gillette
# City not found. Skipping...
# Processing Record 301 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=srednekolymsk
# Processing Record 302 | Whitianga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=whitianga
# Processing Record 303 | Marsaxlokk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=marsaxlokk
# Processing Record 304 | San Francisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=san francisco
# Processing Record 305 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=guerrero negro
# Processing Record 306 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=codrington
# Processing Record 307 | Garoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=garoua
# Processing Record 308 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=meulaboh
# Processing Record 309 | Cumaral
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cumaral
# Processing Record 310 | Bafq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bafq
# City not found. Skipping...
# Processing Record 311 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ilulissat
# Processing Record 312 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=deputatskiy
# Processing Record 313 | Eydhafushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=eydhafushi
# Processing Record 314 | Sabana de Torres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sabana de torres
# Processing Record 315 | Santa Maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=santa maria
# Processing Record 316 | Valle de Allende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=valle de allende
# Processing Record 317 | Mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mahibadhoo
# Processing Record 318 | Nizhniy Tsasuchey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nizhniy tsasuchey
# Processing Record 319 | Mampong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mampong
# Processing Record 320 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=makakilo city
# Processing Record 321 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=alofi
# Processing Record 322 | Paamiut
# ...
# Processing Record 444 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ketchikan
# Processing Record 445 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lata
# City not found. Skipping...
# Processing Record 446 | Newport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=newport
# Processing Record 447 | Sabzevar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sabzevar
# Processing Record 448 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=isangel
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 449 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kirakira
# Processing Record 450 | Batagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=batagay
# Processing Record 451 | Awbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=awbari
# Processing Record 452 | Batticaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=batticaloa
# Processing Record 453 | Zholymbet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=zholymbet
# Processing Record 454 | Waddan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=waddan
# Processing Record 455 | Mana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mana
# Processing Record 456 | Pascagoula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pascagoula
# Processing Record 457 | Phichit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=phichit
# Processing Record 458 | Conceicao do Castelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=conceicao do castelo
# City not found. Skipping...
# Processing Record 459 | Asmara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=asmara
# Processing Record 460 | Caceres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=caceres
# Processing Record 461 | Sao Gabriel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sao gabriel
# Processing Record 462 | Sergeyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sergeyevka
# Processing Record 463 | Sulangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sulangan
# City not found. Skipping...
# Processing Record 464 | Najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=najran
# City not found. Skipping...
# Processing Record 465 | Shepsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=shepsi
# Processing Record 466 | Alexandria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=alexandria
# Processing Record 467 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=okhotsk
# Processing Record 468 | Karasuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=karasuk
# Processing Record 469 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=beringovskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 470 | Obala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=obala
# Processing Record 471 | Pouembout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pouembout
# City not found. Skipping...
# Processing Record 472 | Decatur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=decatur
# Processing Record 473 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=leningradskiy
# Processing Record 474 | Griffith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=griffith
# Processing Record 475 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=naze
# Processing Record 476 | Birjand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=birjand
# Processing Record 477 | Vieste
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vieste
# Processing Record 478 | Makaryev
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=makaryev
# Processing Record 479 | Weihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=weihe
# Processing Record 480 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=padang
# City not found. Skipping...
# Processing Record 481 | Maykor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=maykor
# Processing Record 482 | Praia da Vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=praia da vitoria
# Processing Record 483 | Katherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=katherine
# Processing Record 484 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hambantota
# Processing Record 485 | Schotten
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=schotten
# Processing Record 486 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lorengau
# Processing Record 487 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=belaya gora
# Processing Record 488 | Estevan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=estevan
# Processing Record 489 | Tres Arroyos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tres arroyos
# Processing Record 490 | Puerto Escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=puerto escondido
# Processing Record 491 | Mgachi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mgachi
# Processing Record 492 | Timbuktu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tombouctou
# City not found. Skipping...
# Processing Record 493 | Esna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=esna
# Processing Record 494 | Santa Luzia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=santa luzia
# Processing Record 495 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=shimoda
# Processing Record 496 | Luba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=luba
# Processing Record 497 | Tabuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tabuk
# City not found. Skipping...
# Processing Record 498 | Icod de los Vinos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=icod de los vinos
# Processing Record 499 | Valdosta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=valdosta
# Processing Record 500 | Ouesso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ouesso
# Processing Record 501 | Princeton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=princeton
# Processing Record 502 | Malchevskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=malchevskaya
# Processing Record 503 | Saint-Joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=saint-joseph
# Processing Record 504 | Jaggayyapeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=jaggayyapeta
# Processing Record 505 | Knysna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=knysna
# Processing Record 506 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=port-gentil
# City not found. Skipping...
# Processing Record 507 | Asyut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=asyut
# Processing Record 508 | Soria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=soria
# Processing Record 509 | Battle Creek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=battle creek
# Processing Record 510 | Trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=trairi
# Processing Record 511 | Klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=klyuchi
# City not found. Skipping...
# Processing Record 512 | Yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=yeppoon
# Processing Record 513 | Buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=buin
# Processing Record 514 | Damavand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=damavand
# Processing Record 515 | Segou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=segou
# Processing Record 516 | Vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vestmanna
# Processing Record 517 | Roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=roebourne
# Processing Record 518 | Lakota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lakota
# Processing Record 519 | Baie-Comeau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=baie-comeau
# Processing Record 520 | Beaufort
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=beaufort
# Processing Record 521 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=arlit
# City not found. Skipping...
# Processing Record 522 | Tarbes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tarbes
# Processing Record 523 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kununurra
# Processing Record 524 | Khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=khandyga
# Processing Record 525 | Seaside
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=seaside
# City not found. Skipping...
# Processing Record 526 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bubaque
# Processing Record 527 | Caucaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=caucaia
# Processing Record 528 | Northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=northam
# City not found. Skipping...
# Processing Record 529 | Moindou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=moindou
# Processing Record 530 | Moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=moron
# Processing Record 531 | Issia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=issia
# Processing Record 532 | Shitanjing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=shitanjing
# Processing Record 533 | Bamiantong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bamiantong
# Processing Record 534 | Pokhara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pokhara
# City not found. Skipping...
# Processing Record 535 | Rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=rioja
# Processing Record 536 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sinnamary
# Processing Record 537 | Igarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=igarka
# Processing Record 538 | Rach Gia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=rach gia
# Processing Record 539 | Metsavan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=metsavan
# Processing Record 540 | Melville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=melville
# Processing Record 541 | Lazaro Cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lazaro cardenas
# Processing Record 542 | Joshimath
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=joshimath
# Processing Record 543 | Semnan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=semnan
# Processing Record 544 | Evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=evensk
# Processing Record 545 | Umm Lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=umm lajj
# Processing Record 546 | Tamandare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tamandare
# City not found. Skipping...
# Processing Record 547 | Poquoson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=poquoson
# City not found. Skipping...
# Processing Record 548 | Kishi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kishi
# Processing Record 549 | Shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=shenjiamen

# %%
# Create a dictionary 
weatherpy_dict = {
    "City": city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}

# Create a DataFrame using dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Remove NaN rows and Count of weather data
weather_data = weather_data.dropna()
weather_data.count()
# Out:
# City          549
# Cloudiness    549
# Country       549
# Date          549
# Humidity      549
# Lat           549
# Lng           549
# Max Temp      549
# Wind Speed    549
# dtype: int64

# %%
# Save DataFrame to CSV
weather_data.to_csv("Plot_Outputs/weather_data.csv")

# %%
# Display DataFrame Head
weather_data.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Beloha           2      MG  1559362547        96 -25.17   45.06
# 1   Cape Town          90      ZA  1559362331       100 -33.93   18.42
# 2    Moratuwa          20      LK  1559362549        79   6.77   79.88
# 3  San Miguel          90      AR  1559362552       100 -34.54  -58.72
# 4       Bluff          67      AU  1559362553        31 -23.58  149.07
#
#    Max Temp  Wind Speed
# 0     63.06        5.21
# 1     53.01        2.24
# 2     84.20        6.93
# 3     59.00        3.38
# 4     66.30       10.76

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Scatter Plot - Latitude vs. Temperature Plot
# Used hexagon1 as marker

plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="h", s = max_temp * 10, color = 'royalblue', edgecolor="mediumblue", alpha=0.3, linewidth = 1.0)

# Graph Properties
plt.title("City Latitude vs. Max Temperature (5/31/19)", weight = 'semibold', fontsize = 14)
plt.xlabel("Latitude", weight = 'semibold', fontsize = 12)
plt.ylabel("Max temperature (F)", weight = 'semibold', fontsize = 12)
plt.grid(color='#BDC3C7', linewidth=.50)
plt.vlines(0,-30,150)
plt.text(-5,15,'equator', rotation=90, fontsize = 11)

# Save Scatter Plot
# Resolution is measured as the number of color pixel dot per inch (dpi)
# The standard dpi is 96, poster quality is 300 but it's a much bigger file
plt.savefig("Plot_Outputs/City_Lat_vs_Max_temp.png", bbox_inches="tight", dpi=150)


#Show Scatter Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Scatter Plot - Latitude vs. Humidity Plot
# Used hexagon1 as marker
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="h", s = humidity * 10, color = 'royalblue', edgecolor="mediumblue", alpha=0.3, linewidth = 1.0, zorder=2)

# Graph Properties
plt.title("City Latitude vs. Humidity (5/31/19)", weight = 'semibold', fontsize = 14)
plt.xlabel("Latitude", weight = 'semibold', fontsize = 12)
plt.ylabel("Humidity (%)", weight = 'semibold', fontsize = 12)
plt.grid(color='#BDC3C7', linewidth=.50)
plt.vlines(0, -20, 120)
plt.text(-5,10,'equator', rotation=90, fontsize = 11)



# Save Scatter Plot
# Resolution is measured as the number of color pixel dot per inch (dpi)
# The standard dpi is 96, poster quality is 300 but it's a much bigger file
plt.savefig("Plot_Outputs/City_Lat_vs_Humidity.png", bbox_inches="tight", dpi=150)

#Show Scatter Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Scatter Plot - Latitude vs. Cloudiness Plot
# Used hexagon1 as marker
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="h", s = cloudiness * 10, color = 'royalblue', edgecolor="mediumblue", alpha=0.3, linewidth = 1.0, zorder=2)

# Graph Properties
plt.title("City Latitude vs. Cloudiness (5/31/19)", weight = 'semibold', fontsize = 14)
plt.xlabel("Latitude", weight = 'semibold', fontsize = 12)
plt.ylabel("Cloudiness (%)", weight = 'semibold', fontsize = 12)
plt.grid(color='#BDC3C7', linewidth=.50)
plt.vlines(0, -20, 120)
plt.text(-5,10,'equator', rotation=90, fontsize = 11)


# Save Scatter Plot
# Resolution is measured as the number of color pixel dot per inch (dpi)
# The standard dpi is 96, poster quality is 300 but it's a much bigger file
plt.savefig("Plot_Outputs/City_Lat_vs_Cloudiness.png", bbox_inches="tight", dpi=150)

#Show Scatter Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Scatter Plot - Latitude vs. Wind Speed Plot
# Used hexagon1 as marker
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="h", s = wind_speed * 10, color = 'royalblue', edgecolor="mediumblue", alpha=0.5, linewidth = 1.0, zorder=2)

# Graph Properties
plt.title("City Latitude vs. Wind Speed (5/31/19)", weight = 'semibold', fontsize = 14)
plt.xlabel("Latitude", weight = 'semibold', fontsize = 12)
plt.ylabel("Wind Speed (mph)", weight = 'semibold', fontsize = 12)
plt.grid(color='#BDC3C7', linewidth=.50)
plt.vlines(0,-5,60)
plt.text(-5,50,'equator', rotation=90, fontsize = 11)

# Save Scatter Plot
# Resolution is measured as the number of color pixel dot per inch (dpi)
# The standard dpi is 96, poster quality is 300 but it's a much bigger file
plt.savefig("Plot_Outputs/City_Lat_vs_WindSpeed.png", bbox_inches="tight", dpi=150)

#Show Scatter Plot
plt.show()
