# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt #Plot scatterplots
import pandas as pd #Dataframes and export it to work with it further
import numpy as np #Get random list for lat & long
import requests #Be able to get our data
import time #Get current date for plot title
import urllib #Help build query URL
from citipy import citipy #Get location using lat & long
import matplotlib as mpl

# %%
# Output File (CSV) - Specifies output folder & the file name that we want
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
# set the style as 'bmh'
mpl.style.use('bmh')


# Import API key
from api_keys import api_key
import api_keys

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# %%
# Create a set of random lat and lng combinations
# Using Numpy libraries 
# Using 1500 because we want at least 500 cities

lats = np.random.uniform(low=-90.00, high=90.00, size=1500)
lngs = np.random.uniform(low=-180.00, high=180.00, size=1500)

# Zip through them to easy allow loop through them and find the city names
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
# Looping through our lat long list 
# Using citipy to find the city name nearest to that lat long combination and then we store that city name
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count. To see how many unique cities we get
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Weather API Key
# Storing API Key 
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
# Base URL plus API Key
# Units Imperial because we want our weather to be in Fahrenheit
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# If we click on the link below, we won't get results because we haven't specified a city yet
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4

# %%
# List of city data
# This will store city data when we use our API call
city_data = []

# %%
# Print to Logger
print("Beginning Data Retrieval")
print("-"*25)

# Create Counters to see how many calls we've done
record_count = 1
set_count = 1

# Loop through all the cities in our list
# Using enumerate because it allows us to loop through a list and have an automatic counter
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    # Every 50 cities, add 1 to the set count and then reset record count to 0
    if (i % 50 == 0 and i >= 50):
        set_count += 0
        record_count = 0
        
    # Create Endpoint URL with each city
    # Using URL that we built above and then adding the city name
    city_url = url + "&q=" + urllib.request.pathname2url(city)
    
    # Log the url, record and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    print(city_url)
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try: 
        # Parse the JSON and retrieve data
        # Storing JSON version of the data in the city_weather
        city_weather = requests.get(city_url).json()
        
        # Parse out the max temp, humidity, cloudiness and wind speed
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lng"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_data = city_weather['dt']
        
        # Append the city information into city_data
        city_data.append({'City': city,
                         'Lat': lat,
                         'Lng': lng,
                         'Max Temp': city_max_temp,
                         'Humidity': city_humidity,
                         'Cloudiness': city_clouds,
                         'Wind Speed': city_wind,
                         'Country': city_country,
                         'Date': city_data})
        
    # If an error is experienced, skip the city
    except:
        print("City not found, Skipping...")
        pass
    
# Indicate that Data Loading is complete
print("-"*50)
print("Data Retrieval Compelete")
print("-"*50)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=busselton
# City not found, Skipping...
# Processing Record 2 of Set 1 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=alice%20springs
# City not found, Skipping...
# Processing Record 3 of Set 1 | gurgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=gurgan
# City not found, Skipping...
# Processing Record 4 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mataura
# City not found, Skipping...
# Processing Record 5 of Set 1 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ponta%20delgada
# City not found, Skipping...
# Processing Record 6 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=punta%20arenas
# City not found, Skipping...
# Processing Record 7 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vaini
# City not found, Skipping...
# Processing Record 8 of Set 1 | cuamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cuamba
# City not found, Skipping...
# Processing Record 9 of Set 1 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=amderma
# City not found, Skipping...
# Processing Record 10 of Set 1 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=yulara
# City not found, Skipping...
# Processing Record 11 of Set 1 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sinnamary
# City not found, Skipping...
# Processing Record 12 of Set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ponta%20do%20sol
# City not found, Skipping...
# Processing Record 13 of Set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=port%20elizabeth
# City not found, Skipping...
# Processing Record 14 of Set 1 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=shimoda
# City not found, Skipping...
# Processing Record 15 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kapaa
# City not found, Skipping...
# Processing Record 16 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ushuaia
# City not found, Skipping...
# Processing Record 17 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=taolanaro
# City not found, Skipping...
# Processing Record 18 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=dikson
# City not found, Skipping...
# Processing Record 19 of Set 1 | mahon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mahon
# City not found, Skipping...
# Processing Record 20 of Set 1 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=leningradskiy
# City not found, Skipping...
# Processing Record 21 of Set 1 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=whitehorse
# City not found, Skipping...
# Processing Record 22 of Set 1 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bubaque
# City not found, Skipping...
# Processing Record 23 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=saskylakh
# City not found, Skipping...
# Processing Record 24 of Set 1 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vao
# City not found, Skipping...
# Processing Record 25 of Set 1 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=saint-pierre
# City not found, Skipping...
# Processing Record 26 of Set 1 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mandalgovi
# City not found, Skipping...
# Processing Record 27 of Set 1 | fray bentos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=fray%20bentos
# City not found, Skipping...
# Processing Record 28 of Set 1 | seabra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=seabra
# City not found, Skipping...
# Processing Record 29 of Set 1 | mongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mongo
# City not found, Skipping...
# Processing Record 30 of Set 1 | pringsewu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pringsewu
# City not found, Skipping...
# Processing Record 31 of Set 1 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=goderich
# City not found, Skipping...
# Processing Record 32 of Set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=chuy
# City not found, Skipping...
# Processing Record 33 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=rikitea
# City not found, Skipping...
# Processing Record 34 of Set 1 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cabo%20san%20lucas
# City not found, Skipping...
# Processing Record 35 of Set 1 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tiarei
# City not found, Skipping...
# Processing Record 36 of Set 1 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hami
# City not found, Skipping...
# Processing Record 37 of Set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=upernavik
# City not found, Skipping...
# Processing Record 38 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cape%20town
# City not found, Skipping...
# Processing Record 39 of Set 1 | fereydun kenar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=fereydun%20kenar
# City not found, Skipping...
# Processing Record 40 of Set 1 | lipany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lipany
# City not found, Skipping...
# Processing Record 41 of Set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tuatapere
# City not found, Skipping...
# Processing Record 42 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=yellowknife
# City not found, Skipping...
# Processing Record 43 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=atuona
# City not found, Skipping...
# Processing Record 44 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hermanus
# City not found, Skipping...
# Processing Record 45 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hobart
# City not found, Skipping...
# Processing Record 46 of Set 1 | moyale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=moyale
# City not found, Skipping...
# Processing Record 47 of Set 1 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=beringovskiy
# City not found, Skipping...
# Processing Record 48 of Set 1 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=talnakh
# City not found, Skipping...
# Processing Record 49 of Set 1 | kholtoson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kholtoson
# City not found, Skipping...
# Processing Record 50 of Set 1 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=airai
# City not found, Skipping...
# Processing Record 0 of Set 1 | ocampo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ocampo
# City not found, Skipping...
# Processing Record 1 of Set 1 | muqui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=muqui
# City not found, Skipping...
# Processing Record 2 of Set 1 | bressuire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bressuire
# City not found, Skipping...
# Processing Record 3 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=albany
# City not found, Skipping...
# Processing Record 4 of Set 1 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=praia%20da%20vitoria
# City not found, Skipping...
# Processing Record 5 of Set 1 | byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=byron%20bay
# City not found, Skipping...
# Processing Record 6 of Set 1 | murray bridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=murray%20bridge
# City not found, Skipping...
# Processing Record 7 of Set 1 | kaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kaka
# City not found, Skipping...
# Processing Record 8 of Set 1 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nizhneyansk
# City not found, Skipping...
# Processing Record 9 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=chokurdakh
# City not found, Skipping...
# Processing Record 10 of Set 1 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=illoqqortoormiut
# City not found, Skipping...
# Processing Record 11 of Set 1 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=grand%20gaube
# City not found, Skipping...
# Processing Record 12 of Set 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bengkulu
# City not found, Skipping...
# Processing Record 13 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hilo
# City not found, Skipping...
# Processing Record 14 of Set 1 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=constitucion
# City not found, Skipping...
# Processing Record 15 of Set 1 | ritchie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ritchie
# City not found, Skipping...
# Processing Record 16 of Set 1 | bernalillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bernalillo
# City not found, Skipping...
# Processing Record 17 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hithadhoo
# City not found, Skipping...
# Processing Record 18 of Set 1 | jardim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=jardim
# City not found, Skipping...
# Processing Record 19 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cidreira
# City not found, Skipping...
# Processing Record 20 of Set 1 | nandura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nandura
# City not found, Skipping...
# Processing Record 21 of Set 1 | hihifo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hihifo
# City not found, Skipping...
# Processing Record 22 of Set 1 | nakamura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nakamura
# City not found, Skipping...
# Processing Record 23 of Set 1 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ilulissat
# City not found, Skipping...
# Processing Record 24 of Set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=severo-kurilsk
# City not found, Skipping...
# Processing Record 25 of Set 1 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=saint-joseph
# City not found, Skipping...
# Processing Record 26 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=provideniya
# City not found, Skipping...
# Processing Record 27 of Set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kodiak
# City not found, Skipping...
# Processing Record 28 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=new%20norfolk
# City not found, Skipping...
# Processing Record 29 of Set 1 | haibowan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=haibowan
# City not found, Skipping...
# Processing Record 30 of Set 1 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=udachnyy
# City not found, Skipping...
# Processing Record 31 of Set 1 | bay roberts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bay%20roberts
# City not found, Skipping...
# Processing Record 32 of Set 1 | kattivakkam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kattivakkam
# City not found, Skipping...
# Processing Record 33 of Set 1 | aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=aksu
# City not found, Skipping...
# Processing Record 34 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=port%20alfred
# City not found, Skipping...
# Processing Record 35 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=khatanga
# City not found, Skipping...
# Processing Record 36 of Set 1 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kamenskoye
# City not found, Skipping...
# Processing Record 37 of Set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=longyearbyen
# City not found, Skipping...
# Processing Record 38 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=arraial%20do%20cabo
# City not found, Skipping...
# Processing Record 39 of Set 1 | tavira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tavira
# City not found, Skipping...
# Processing Record 40 of Set 1 | catuday
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=catuday
# City not found, Skipping...
# Processing Record 41 of Set 1 | panama city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=panama%20city
# City not found, Skipping...
# Processing Record 42 of Set 1 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=victoria
# City not found, Skipping...
# Processing Record 43 of Set 1 | aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=aksarka
# City not found, Skipping...
# Processing Record 44 of Set 1 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=oranjemund
# City not found, Skipping...
# Processing Record 45 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ribeira%20grande
# City not found, Skipping...
# Processing Record 46 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=butaritari
# City not found, Skipping...
# Processing Record 47 of Set 1 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=luanda
# City not found, Skipping...
# Processing Record 48 of Set 1 | asyut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=asyut
# City not found, Skipping...
# Processing Record 49 of Set 1 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sentyabrskiy
# City not found, Skipping...
# Processing Record 0 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bluff
# City not found, Skipping...
# Processing Record 1 of Set 1 | felipe carrillo puerto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=felipe%20carrillo%20puerto
# City not found, Skipping...
# Processing Record 2 of Set 1 | kailua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kailua
# City not found, Skipping...
# Processing Record 3 of Set 1 | rabo de peixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=rabo%20de%20peixe
# City not found, Skipping...
# Processing Record 4 of Set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=belushya%20guba
# City not found, Skipping...
# Processing Record 5 of Set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=iqaluit
# City not found, Skipping...
# Processing Record 6 of Set 1 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=maragogi
# City not found, Skipping...
# Processing Record 7 of Set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lebu
# City not found, Skipping...
# Processing Record 8 of Set 1 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=usinsk
# City not found, Skipping...
# Processing Record 9 of Set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=barentsburg
# City not found, Skipping...
# Processing Record 10 of Set 1 | roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=roma
# City not found, Skipping...
# Processing Record 11 of Set 1 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sao%20joao%20da%20barra
# City not found, Skipping...
# Processing Record 12 of Set 1 | mokhotlong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mokhotlong
# City not found, Skipping...
# Processing Record 13 of Set 1 | kommunar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kommunar
# City not found, Skipping...
# Processing Record 14 of Set 1 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=flinders
# City not found, Skipping...
# Processing Record 15 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=saint-philippe
# City not found, Skipping...
# Processing Record 16 of Set 1 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mitu
# City not found, Skipping...
# Processing Record 17 of Set 1 | yurgamysh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=yurgamysh
# City not found, Skipping...
# Processing Record 18 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=qaanaaq
# City not found, Skipping...
# Processing Record 19 of Set 1 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lagoa
# City not found, Skipping...
# Processing Record 20 of Set 1 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tura
# City not found, Skipping...
# Processing Record 21 of Set 1 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=faanui
# City not found, Skipping...
# Processing Record 22 of Set 1 | manzanillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=manzanillo
# City not found, Skipping...
# Processing Record 23 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=georgetown
# City not found, Skipping...
# Processing Record 24 of Set 1 | malakal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=malakal
# City not found, Skipping...
# Processing Record 25 of Set 1 | chake chake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=chake%20chake
# City not found, Skipping...
# Processing Record 26 of Set 1 | dzilam gonzalez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=dzilam%20gonzalez
# City not found, Skipping...
# Processing Record 27 of Set 1 | olavarria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=olavarria
# City not found, Skipping...
# Processing Record 28 of Set 1 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=narsaq
# City not found, Skipping...
# Processing Record 29 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=carnarvon
# City not found, Skipping...
# Processing Record 30 of Set 1 | kapuskasing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kapuskasing
# City not found, Skipping...
# Processing Record 31 of Set 1 | moose factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=moose%20factory
# City not found, Skipping...
# Processing Record 32 of Set 1 | homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=homer
# City not found, Skipping...
# Processing Record 33 of Set 1 | yangambi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=yangambi
# City not found, Skipping...
# Processing Record 34 of Set 1 | roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=roald
# City not found, Skipping...
# Processing Record 35 of Set 1 | mandera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mandera
# City not found, Skipping...
# Processing Record 36 of Set 1 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nabire
# City not found, Skipping...
# Processing Record 37 of Set 1 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=havre-saint-pierre
# City not found, Skipping...
# Processing Record 38 of Set 1 | pervomayskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pervomayskoye
# City not found, Skipping...
# Processing Record 39 of Set 1 | visby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=visby
# City not found, Skipping...
# Processing Record 40 of Set 1 | niksic
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=niksic
# City not found, Skipping...
# Processing Record 41 of Set 1 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lavrentiya
# City not found, Skipping...
# Processing Record 42 of Set 1 | tarko-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tarko-sale
# City not found, Skipping...
# Processing Record 43 of Set 1 | portel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=portel
# City not found, Skipping...
# Processing Record 44 of Set 1 | evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=evensk
# City not found, Skipping...
# Processing Record 45 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=jamestown
# City not found, Skipping...
# Processing Record 46 of Set 1 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cockburn%20town
# City not found, Skipping...
# Processing Record 47 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=thompson
# City not found, Skipping...
# Processing Record 48 of Set 1 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=isangel
# City not found, Skipping...
# Processing Record 49 of Set 1 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cap%20malheureux
# City not found, Skipping...
# Processing Record 0 of Set 1 | cariamanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cariamanga
# City not found, Skipping...
# Processing Record 1 of Set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=torbay
# City not found, Skipping...
# Processing Record 2 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=puerto%20ayora
# City not found, Skipping...
# Processing Record 3 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bethel
# City not found, Skipping...
# Processing Record 4 of Set 1 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bandarbeyla
# City not found, Skipping...
# Processing Record 5 of Set 1 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=korla
# City not found, Skipping...
# Processing Record 6 of Set 1 | mayumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mayumba
# City not found, Skipping...
# Processing Record 7 of Set 1 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bonthe
# City not found, Skipping...
# Processing Record 8 of Set 1 | sturgeon falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sturgeon%20falls
# City not found, Skipping...
# Processing Record 9 of Set 1 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=qaqortoq
# City not found, Skipping...
# Processing Record 10 of Set 1 | komnina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=komnina
# City not found, Skipping...
# Processing Record 11 of Set 1 | tashtagol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tashtagol
# City not found, Skipping...
# Processing Record 12 of Set 1 | tsiroanomandidy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tsiroanomandidy
# City not found, Skipping...
# Processing Record 13 of Set 1 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=san%20patricio
# City not found, Skipping...
# Processing Record 14 of Set 1 | paradwip
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=paradwip
# City not found, Skipping...
# Processing Record 15 of Set 1 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=alta%20floresta
# City not found, Skipping...
# Processing Record 16 of Set 1 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=plettenberg%20bay
# City not found, Skipping...
# Processing Record 17 of Set 1 | bahia honda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bahia%20honda
# City not found, Skipping...
# Processing Record 18 of Set 1 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=camacha
# City not found, Skipping...
# Processing Record 19 of Set 1 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pisco
# City not found, Skipping...
# Processing Record 20 of Set 1 | mayor pablo lagerenza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mayor%20pablo%20lagerenza
# City not found, Skipping...
# Processing Record 21 of Set 1 | yirol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=yirol
# City not found, Skipping...
# Processing Record 22 of Set 1 | cabra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cabra
# City not found, Skipping...
# Processing Record 23 of Set 1 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=deputatskiy
# City not found, Skipping...
# Processing Record 24 of Set 1 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pangnirtung
# City not found, Skipping...
# Processing Record 25 of Set 1 | isla mujeres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=isla%20mujeres
# City not found, Skipping...
# Processing Record 26 of Set 1 | san vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=san%20vicente
# City not found, Skipping...
# Processing Record 27 of Set 1 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hofn
# City not found, Skipping...
# Processing Record 28 of Set 1 | praya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=praya
# City not found, Skipping...
# Processing Record 29 of Set 1 | bichena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bichena
# City not found, Skipping...
# Processing Record 30 of Set 1 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=havelock
# City not found, Skipping...
# Processing Record 31 of Set 1 | ucluelet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ucluelet
# City not found, Skipping...
# Processing Record 32 of Set 1 | griffith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=griffith
# City not found, Skipping...
# Processing Record 33 of Set 1 | fevralsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=fevralsk
# City not found, Skipping...
# Processing Record 34 of Set 1 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=fortuna
# City not found, Skipping...
# Processing Record 35 of Set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=saint%20george
# City not found, Skipping...
# Processing Record 36 of Set 1 | barabai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=barabai
# City not found, Skipping...
# Processing Record 37 of Set 1 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=salalah
# City not found, Skipping...
# Processing Record 38 of Set 1 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kruisfontein
# City not found, Skipping...
# Processing Record 39 of Set 1 | mugur-aksy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mugur-aksy
# City not found, Skipping...
# Processing Record 40 of Set 1 | rovaniemi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=rovaniemi
# City not found, Skipping...
# Processing Record 41 of Set 1 | neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=neiafu
# City not found, Skipping...
# Processing Record 42 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=castro
# City not found, Skipping...
# Processing Record 43 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tuktoyaktuk
# City not found, Skipping...
# Processing Record 44 of Set 1 | makurdi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=makurdi
# City not found, Skipping...
# Processing Record 45 of Set 1 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sioux%20lookout
# City not found, Skipping...
# Processing Record 46 of Set 1 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=broome
# City not found, Skipping...
# Processing Record 47 of Set 1 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=meulaboh
# City not found, Skipping...
# Processing Record 48 of Set 1 | gorno-chuyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=gorno-chuyskiy
# City not found, Skipping...
# Processing Record 49 of Set 1 | khromtau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=khromtau
# City not found, Skipping...
# Processing Record 0 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bredasdorp
# City not found, Skipping...
# Processing Record 1 of Set 1 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vestmannaeyjar
# City not found, Skipping...
# Processing Record 2 of Set 1 | ramsgate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ramsgate
# City not found, Skipping...
# Processing Record 3 of Set 1 | sant feliu de guixols
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sant%20feliu%20de%20guixols
# City not found, Skipping...
# Processing Record 4 of Set 1 | maseru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=maseru
# City not found, Skipping...
# Processing Record 5 of Set 1 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cayenne
# City not found, Skipping...
# Processing Record 6 of Set 1 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=saldanha
# City not found, Skipping...
# Processing Record 7 of Set 1 | jabiru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=jabiru
# City not found, Skipping...
# Processing Record 8 of Set 1 | prabumulih
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=prabumulih
# City not found, Skipping...
# Processing Record 9 of Set 1 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=attawapiskat
# City not found, Skipping...
# Processing Record 10 of Set 1 | soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=soyo
# City not found, Skipping...
# Processing Record 11 of Set 1 | sand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sand
# City not found, Skipping...
# Processing Record 12 of Set 1 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tsihombe
# City not found, Skipping...
# Processing Record 13 of Set 1 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=xining
# City not found, Skipping...
# Processing Record 14 of Set 1 | san carlos de bariloche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=san%20carlos%20de%20bariloche
# City not found, Skipping...
# Processing Record 15 of Set 1 | hirado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hirado
# City not found, Skipping...
# Processing Record 16 of Set 1 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vila%20velha
# City not found, Skipping...
# Processing Record 17 of Set 1 | belawan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=belawan
# City not found, Skipping...
# Processing Record 18 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tasiilaq
# City not found, Skipping...
# Processing Record 19 of Set 1 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=richards%20bay
# City not found, Skipping...
# Processing Record 20 of Set 1 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vaitupu
# City not found, Skipping...
# Processing Record 21 of Set 1 | san benito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=san%20benito
# City not found, Skipping...
# Processing Record 22 of Set 1 | chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=chara
# City not found, Skipping...
# Processing Record 23 of Set 1 | moindou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=moindou
# City not found, Skipping...
# Processing Record 24 of Set 1 | payo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=payo
# City not found, Skipping...
# Processing Record 25 of Set 1 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=flin%20flon
# City not found, Skipping...
# Processing Record 26 of Set 1 | ferrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ferrol
# City not found, Skipping...
# Processing Record 27 of Set 1 | orlik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=orlik
# City not found, Skipping...
# Processing Record 28 of Set 1 | qabis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=qabis
# City not found, Skipping...
# Processing Record 29 of Set 1 | kalianget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kalianget
# City not found, Skipping...
# Processing Record 30 of Set 1 | vesele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vesele
# City not found, Skipping...
# Processing Record 31 of Set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nanortalik
# City not found, Skipping...
# Processing Record 32 of Set 1 | pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pochutla
# City not found, Skipping...
# Processing Record 33 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=klaksvik
# City not found, Skipping...
# Processing Record 34 of Set 1 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=los%20llanos%20de%20aridane
# City not found, Skipping...
# Processing Record 35 of Set 1 | ashukino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ashukino
# City not found, Skipping...
# Processing Record 36 of Set 1 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=port%20lincoln
# City not found, Skipping...
# Processing Record 37 of Set 1 | prince albert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=prince%20albert
# City not found, Skipping...
# Processing Record 38 of Set 1 | kohima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kohima
# City not found, Skipping...
# Processing Record 39 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mar%20del%20plata
# City not found, Skipping...
# Processing Record 40 of Set 1 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=brae
# City not found, Skipping...
# Processing Record 41 of Set 1 | rizhao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=rizhao
# City not found, Skipping...
# Processing Record 42 of Set 1 | bargal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=bargal
# City not found, Skipping...
# Processing Record 43 of Set 1 | otavi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=otavi
# City not found, Skipping...
# Processing Record 44 of Set 1 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=te%20anau
# City not found, Skipping...
# Processing Record 45 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nikolskoye
# City not found, Skipping...
# Processing Record 46 of Set 1 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=umm%20lajj
# City not found, Skipping...
# Processing Record 47 of Set 1 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=aswan
# City not found, Skipping...
# Processing Record 48 of Set 1 | qesarya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=qesarya
# City not found, Skipping...
# Processing Record 49 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=avarua
# City not found, Skipping...
# Processing Record 0 of Set 1 | barbar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=barbar
# City not found, Skipping...
# Processing Record 1 of Set 1 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lasa
# City not found, Skipping...
# Processing Record 2 of Set 1 | daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=daru
# City not found, Skipping...
# Processing Record 3 of Set 1 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=palmer
# City not found, Skipping...
# Processing Record 4 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mahebourg
# City not found, Skipping...
# Processing Record 5 of Set 1 | samandag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=samandag
# City not found, Skipping...
# Processing Record 6 of Set 1 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=san%20cristobal
# City not found, Skipping...
# Processing Record 7 of Set 1 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mogadishu
# City not found, Skipping...
# Processing Record 8 of Set 1 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mys%20shmidta
# City not found, Skipping...
# Processing Record 9 of Set 1 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=fukue
# City not found, Skipping...
# Processing Record 10 of Set 1 | maturin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=maturin
# City not found, Skipping...
# Processing Record 11 of Set 1 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=portland
# City not found, Skipping...
# Processing Record 12 of Set 1 | margate
# ...
# City not found, Skipping...
# Processing Record 23 of Set 1 | prudy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=prudy
# City not found, Skipping...
# Processing Record 24 of Set 1 | panguipulli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=panguipulli
# City not found, Skipping...
# Processing Record 25 of Set 1 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ambilobe
# City not found, Skipping...
# Processing Record 26 of Set 1 | hendaye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hendaye
# City not found, Skipping...
# Processing Record 27 of Set 1 | phan rang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=phan%20rang
# City not found, Skipping...
# Processing Record 28 of Set 1 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mayo
# City not found, Skipping...
# Processing Record 29 of Set 1 | darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=darhan
# City not found, Skipping...
# Processing Record 30 of Set 1 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=coihaique
# City not found, Skipping...
# Processing Record 31 of Set 1 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=naze
# City not found, Skipping...
# Processing Record 32 of Set 1 | aquiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=aquiraz
# City not found, Skipping...
# Processing Record 33 of Set 1 | ca mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=ca%20mau
# City not found, Skipping...
# Processing Record 34 of Set 1 | agirish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=agirish
# City not found, Skipping...
# Processing Record 35 of Set 1 | morgan city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=morgan%20city
# City not found, Skipping...
# Processing Record 36 of Set 1 | morro bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=morro%20bay
# City not found, Skipping...
# Processing Record 37 of Set 1 | aran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=aran
# City not found, Skipping...
# Processing Record 38 of Set 1 | oxford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=oxford
# City not found, Skipping...
# Processing Record 39 of Set 1 | oxelosund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=oxelosund
# City not found, Skipping...
# Processing Record 40 of Set 1 | yingzhong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=yingzhong
# City not found, Skipping...
# Processing Record 41 of Set 1 | sainte-marie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sainte-marie
# City not found, Skipping...
# Processing Record 42 of Set 1 | morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=morondava
# City not found, Skipping...
# Processing Record 43 of Set 1 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=buala
# City not found, Skipping...
# Processing Record 44 of Set 1 | meyungs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=meyungs
# City not found, Skipping...
# Processing Record 45 of Set 1 | panaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=panaba
# City not found, Skipping...
# Processing Record 46 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=cherskiy
# City not found, Skipping...
# Processing Record 47 of Set 1 | dzhebariki-khaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=dzhebariki-khaya
# City not found, Skipping...
# Processing Record 48 of Set 1 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=henties%20bay
# City not found, Skipping...
# Processing Record 49 of Set 1 | basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=basco
# City not found, Skipping...
# Processing Record 0 of Set 1 | athabasca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=athabasca
# City not found, Skipping...
# Processing Record 1 of Set 1 | slave lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=slave%20lake
# City not found, Skipping...
# Processing Record 2 of Set 1 | hudson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hudson%20bay
# City not found, Skipping...
# Processing Record 3 of Set 1 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kahului
# City not found, Skipping...
# Processing Record 4 of Set 1 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=belyy%20yar
# City not found, Skipping...
# Processing Record 5 of Set 1 | biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=biak
# City not found, Skipping...
# Processing Record 6 of Set 1 | villa guerrero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=villa%20guerrero
# City not found, Skipping...
# Processing Record 7 of Set 1 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=abu%20samrah
# City not found, Skipping...
# Processing Record 8 of Set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kaitangata
# City not found, Skipping...
# Processing Record 9 of Set 1 | san ramon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=san%20ramon
# City not found, Skipping...
# Processing Record 10 of Set 1 | darasun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=darasun
# City not found, Skipping...
# Processing Record 11 of Set 1 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=coahuayana
# City not found, Skipping...
# Processing Record 12 of Set 1 | kargasok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kargasok
# City not found, Skipping...
# Processing Record 13 of Set 1 | smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=smithers
# City not found, Skipping...
# Processing Record 14 of Set 1 | nanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nanning
# City not found, Skipping...
# Processing Record 15 of Set 1 | mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=mercedes
# City not found, Skipping...
# Processing Record 16 of Set 1 | kenora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kenora
# City not found, Skipping...
# Processing Record 17 of Set 1 | myaundzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=myaundzha
# City not found, Skipping...
# Processing Record 18 of Set 1 | pafos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pafos
# City not found, Skipping...
# Processing Record 19 of Set 1 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sola
# City not found, Skipping...
# Processing Record 20 of Set 1 | fujin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=fujin
# City not found, Skipping...
# Processing Record 21 of Set 1 | marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=marienburg
# City not found, Skipping...
# Processing Record 22 of Set 1 | vryburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=vryburg
# City not found, Skipping...
# Processing Record 23 of Set 1 | soto la marina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=soto%20la%20marina
# City not found, Skipping...
# Processing Record 24 of Set 1 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=gizo
# City not found, Skipping...
# Processing Record 25 of Set 1 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lompoc
# City not found, Skipping...
# Processing Record 26 of Set 1 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nelson%20bay
# City not found, Skipping...
# Processing Record 27 of Set 1 | jitia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=jitia
# City not found, Skipping...
# Processing Record 28 of Set 1 | kuytun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kuytun
# City not found, Skipping...
# Processing Record 29 of Set 1 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=port%20hedland
# City not found, Skipping...
# Processing Record 30 of Set 1 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hervey%20bay
# City not found, Skipping...
# Processing Record 31 of Set 1 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=inirida
# City not found, Skipping...
# Processing Record 32 of Set 1 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=yumen
# City not found, Skipping...
# Processing Record 33 of Set 1 | chagda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=chagda
# City not found, Skipping...
# Processing Record 34 of Set 1 | tchollire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=tchollire
# City not found, Skipping...
# Processing Record 35 of Set 1 | nampula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=nampula
# City not found, Skipping...
# Processing Record 36 of Set 1 | arkhangelos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=arkhangelos
# City not found, Skipping...
# Processing Record 37 of Set 1 | zeya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=zeya
# City not found, Skipping...
# Processing Record 38 of Set 1 | santarem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=santarem
# City not found, Skipping...
# Processing Record 39 of Set 1 | sinegorye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sinegorye
# City not found, Skipping...
# Processing Record 40 of Set 1 | elk city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=elk%20city
# City not found, Skipping...
# Processing Record 41 of Set 1 | buritis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=buritis
# City not found, Skipping...
# Processing Record 42 of Set 1 | hargeysa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=hargeysa
# City not found, Skipping...
# Processing Record 43 of Set 1 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=port-gentil
# City not found, Skipping...
# Processing Record 44 of Set 1 | lianran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lianran
# City not found, Skipping...
# Processing Record 45 of Set 1 | lanzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=lanzhou
# City not found, Skipping...
# Processing Record 46 of Set 1 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=san%20policarpo
# City not found, Skipping...
# Processing Record 47 of Set 1 | trail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=trail
# City not found, Skipping...
# Processing Record 48 of Set 1 | kristianstad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kristianstad
# City not found, Skipping...
# Processing Record 49 of Set 1 | sandwick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=sandwick
# City not found, Skipping...
# Processing Record 0 of Set 1 | esna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=esna
# City not found, Skipping...
# Processing Record 1 of Set 1 | talawdi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=talawdi
# City not found, Skipping...
# Processing Record 2 of Set 1 | thessalon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=thessalon
# City not found, Skipping...
# Processing Record 3 of Set 1 | elizabeth city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=elizabeth%20city
# City not found, Skipping...
# Processing Record 4 of Set 1 | batagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=batagay
# City not found, Skipping...
# Processing Record 5 of Set 1 | guozhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=guozhen
# City not found, Skipping...
# Processing Record 6 of Set 1 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=avera
# City not found, Skipping...
# Processing Record 7 of Set 1 | garm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=garm
# City not found, Skipping...
# Processing Record 8 of Set 1 | kijang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=kijang
# City not found, Skipping...
# Processing Record 9 of Set 1 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=703b5369eb2d7f5063246a6ebd46bcb4&q=pacific%20grove
# City not found, Skipping...
# --------------------------------------------------
# Data Retrieval Compelete
# --------------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSONS into Pandas DataFrame
# Reminder: If you don't specify the order, Pandas will put it in Alphabetical order
city_data_pd = pd.DataFrame(city_data)
city_data_pd.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Extract relevant fields from the DataFrame
lats = city_data_pd['Lat']
max_temps = city_data_pd['Max Temp']
humidity = city_data_pd['Humidity']
cloudiness = city_data_pd['Cloudiness']
wind_speed = city_data_pd['Wind Speed']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\LearnPython\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lat'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-89d39e8bd5ed> in <module>
#       1 # Extract relevant fields from the DataFrame
# ----> 2 lats = city_data_pd['Lat']
#       3 max_temps = city_data_pd['Max Temp']
#       4 humidity = city_data_pd['Humidity']
#       5 cloudiness = city_data_pd['Cloudiness']
#
# ~\LearnPython\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\LearnPython\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lat'

# %%
# Export City Data into CSV File
city_data_pd.to_csv(output_data_file, index_label='City_ID')

# %%
# Create a dictionary 
weatherpy_dict = {
    "City": city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}

# Create a DataFrame using dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Remove NaN rows and Count of weather data
weather_data = weather_data.dropna()
weather_data.count()

# %%
# Save DataFrame to CSV
weather_data.to_csv("Plot_Outputs/weather_data.csv")

# %%
# Display DataFrame Head
weather_data.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Scatter Plot - Latitude vs. Temperature Plot
# Used hexagon1 as marker

plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="h", s = max_temp * 10, color = 'royalblue', edgecolor="mediumblue", alpha=0.3, linewidth = 1.0)

# Graph Properties
plt.title("City Latitude vs. Max Temperature (5/31/19)", weight = 'semibold', fontsize = 14)
plt.xlabel("Latitude", weight = 'semibold', fontsize = 12)
plt.ylabel("Max temperature (F)", weight = 'semibold', fontsize = 12)
plt.grid(color='#BDC3C7', linewidth=.50)
plt.vlines(0,-30,150)
plt.text(-5,15,'equator', rotation=90, fontsize = 11)

# Save Scatter Plot
# Resolution is measured as the number of color pixel dot per inch (dpi)
# The standard dpi is 96, poster quality is 300 but it's a much bigger file
plt.savefig("Plot_Outputs/City_Lat_vs_Max_temp.png", bbox_inches="tight", dpi=150)


#Show Scatter Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Scatter Plot - Latitude vs. Humidity Plot
# Used hexagon1 as marker
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="h", s = humidity * 10, color = 'royalblue', edgecolor="mediumblue", alpha=0.3, linewidth = 1.0, zorder=2)

# Graph Properties
plt.title("City Latitude vs. Humidity (5/31/19)", weight = 'semibold', fontsize = 14)
plt.xlabel("Latitude", weight = 'semibold', fontsize = 12)
plt.ylabel("Humidity (%)", weight = 'semibold', fontsize = 12)
plt.grid(color='#BDC3C7', linewidth=.50)
plt.vlines(0, -20, 120)
plt.text(-5,10,'equator', rotation=90, fontsize = 11)



# Save Scatter Plot
# Resolution is measured as the number of color pixel dot per inch (dpi)
# The standard dpi is 96, poster quality is 300 but it's a much bigger file
plt.savefig("Plot_Outputs/City_Lat_vs_Humidity.png", bbox_inches="tight", dpi=150)

#Show Scatter Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Scatter Plot - Latitude vs. Cloudiness Plot
# Used hexagon1 as marker
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="h", s = cloudiness * 10, color = 'royalblue', edgecolor="mediumblue", alpha=0.3, linewidth = 1.0, zorder=2)

# Graph Properties
plt.title("City Latitude vs. Cloudiness (5/31/19)", weight = 'semibold', fontsize = 14)
plt.xlabel("Latitude", weight = 'semibold', fontsize = 12)
plt.ylabel("Cloudiness (%)", weight = 'semibold', fontsize = 12)
plt.grid(color='#BDC3C7', linewidth=.50)
plt.vlines(0, -20, 120)
plt.text(-5,10,'equator', rotation=90, fontsize = 11)


# Save Scatter Plot
# Resolution is measured as the number of color pixel dot per inch (dpi)
# The standard dpi is 96, poster quality is 300 but it's a much bigger file
plt.savefig("Plot_Outputs/City_Lat_vs_Cloudiness.png", bbox_inches="tight", dpi=150)

#Show Scatter Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Scatter Plot - Latitude vs. Wind Speed Plot
# Used hexagon1 as marker
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="h", s = wind_speed * 10, color = 'royalblue', edgecolor="mediumblue", alpha=0.5, linewidth = 1.0, zorder=2)

# Graph Properties
plt.title("City Latitude vs. Wind Speed (5/31/19)", weight = 'semibold', fontsize = 14)
plt.xlabel("Latitude", weight = 'semibold', fontsize = 12)
plt.ylabel("Wind Speed (mph)", weight = 'semibold', fontsize = 12)
plt.grid(color='#BDC3C7', linewidth=.50)
plt.vlines(0,-5,60)
plt.text(-5,50,'equator', rotation=90, fontsize = 11)

# Save Scatter Plot
# Resolution is measured as the number of color pixel dot per inch (dpi)
# The standard dpi is 96, poster quality is 300 but it's a much bigger file
plt.savefig("Plot_Outputs/City_Lat_vs_WindSpeed.png", bbox_inches="tight", dpi=150)

#Show Scatter Plot
plt.show()

# %%
html_table = weather_data.to_html()
html_table
